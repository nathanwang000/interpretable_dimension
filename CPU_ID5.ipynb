# %%
import itertools
from collections import defaultdict
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import os, math
import matplotlib.image as mpimg
import torch
import matplotlib as mpl
from skimage import io
from torch.utils.data.sampler import SubsetRandomSampler, RandomSampler
import copy
from sklearn.decomposition import PCA
import seaborn as sns
import torchvision.models as models
import torch.nn.functional as F
from glob import glob
import cv2
from src.utility import preprocess_image, convert_image_np, getImageNetDict, getImageNetCodeDict
import torch.optim as optim
import torch.nn as nn
import copy, time
from torchvision import transforms, utils
import tqdm
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.autograd import Variable
from collections import Counter
from src.parallel_run import map_parallel
from joblib import Parallel, delayed
import multiprocessing
import os.path
from sklearn.externals import joblib

# %%
alexnet = models.alexnet(pretrained=True)
imagenetdict = getImageNetDict()
imagenetcodedict = getImageNetCodeDict()
name2code = dict((v, k) for k, v in imagenetcodedict.items())
alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d (3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), dilation=(1, 1))
#     (3): Conv2d (64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), dilation=(1, 1))
#     (6): Conv2d (192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d (384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d (256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), dilation=(1, 1))
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000)
#   )
# )

# %%
model = copy.deepcopy(alexnet)
model.classifier = nn.Sequential(*list(alexnet.classifier.children())[:-1])
W = list(alexnet.classifier.children())[-1].weight.cpu().data.numpy()
net = alexnet

# %%
def to_var(x, *args, **kwargs):
    if type(x) is list or type(x) is tuple:
        x = [Variable(x_, *args, **kwargs) for x_ in x]
    else:
        x = Variable(x, *args, **kwargs)
    return x

# display the basis vectors
def preprocess_im(im, volatile=False, resize_im=True):
    original_image = cv2.imread(im)
    prep_img = preprocess_image(original_image, resize_im=resize_im)
    if volatile:
        prep_img.volatile = True
    return prep_img

def show_image(images, title=''):
    seq = []
    for im in images:
        prep_img = preprocess_im(im, volatile=True)
        seq.append(prep_img)
    images_batch = torch.cat(seq, dim=0)
    grid = utils.make_grid(images_batch.data)   
    plt.imshow(convert_image_np(grid))
    plt.title(title)
    plt.gca().grid(False)
    plt.show()
    
def show_concepts(concepts, n_per_concept=8):
    prefix = 'tiny-imagenet-200/train/'
    res = []
    for c in concepts:
        name = prefix + name2code[c]
        all_pics = glob(name + '/images/*')
        rs = np.random.choice(range(len(all_pics)), n_per_concept, replace=False)
        res.extend([all_pics[r] for r in rs])
    
    plt.figure(figsize=(10,10))
    show_image(res)
    plt.show()
    
def generate_basis(concept_class, W):
    n_per_class = math.ceil(W.shape[1] / len(concept_class))
    prefix = 'tiny-imagenet-200/train/'
    res = []
    concepts = []
    for c in concept_class:
        name = prefix + name2code[c]
        all_pics = glob(name + '/images/*')
        rs = np.random.choice(range(len(all_pics)), n_per_class, replace=False)
        res.extend([all_pics[r] for r in rs])
        concepts.extend([name2code[c] for r in rs])
        
    order = np.random.permutation(W.shape[1])
    res = np.array(res)[order]
    concepts = np.array(concepts)[order]
    return res, concepts

def get_test_images(concept_class, anno_path='tiny-imagenet-200/val'):
    anno = anno_path + '/val_annotations.txt'
    d = {}
    with open(anno) as f:
        for l in f:
            k, v = l.split()[:2]
            d[k] = v
            
    prefix = anno_path + '/images/'
    images = []
    labels = []
    for im in glob(prefix + '*'):
        c = d[im.split('/')[-1]]
        if imagenetcodedict[c] in concept_class:
            images.append(im)
            labels.append(c)
    return images, labels

def predict(net, im):
    net.eval()
    prep_img = preprocess_im(im)
    prediction = net(prep_img).data.cpu().numpy().argmax()
    return imagenetdict[prediction], prediction

def extract_features(net, images):
    net.eval()
    seq = []
    for im in tqdm.tqdm(images):
        prep_img = preprocess_im(im, volatile=True)
        seq.append(prep_img)
        
    features = []
    for i in tqdm.tqdm(range(0, len(seq), 100)):
        images_batch = torch.cat(seq[i:i+100], dim=0)
        features.append(net(images_batch))
    return torch.cat(features, dim=0)

def check_ortho(theta_list, plot=False, verbose=False):
    Q = [t/np.linalg.norm(t) for t in theta_list]
    Q = np.vstack(Q).T
    error = np.sum(np.abs(Q.T.dot(Q) - np.eye(Q.shape[1])))
    if verbose:
        print("orthogonal check error: ", error)
    if plot:
        print(Q.T.dot(Q))
        plt.matshow(Q.T.dot(Q))
        plt.show()
    return error
    
def orthogonize_(theta, prev_theta_list):
    '''goal: theta should be orthogonal to all vectors in prev_theta_list'''
    theta = theta / np.linalg.norm(theta)
    for t in prev_theta_list:
        theta = theta - theta.dot(t) / np.dot(t,t) * t 
    return theta

def orthogonize(theta, prev_theta_list, verbose=False):
    done = len(prev_theta_list) == 0
    while not done:
        theta = orthogonize_(theta, prev_theta_list)
        #check_ortho(prev_theta_list, plot=False)        
        #check_ortho(prev_theta_list + [theta], plot=False)
        #print('in middle', theta)
        #print(check_ortho(prev_theta_list + [theta]))
        #if  check_ortho(prev_theta_list + [theta]) > 1e-3:
            #print(check_ortho(prev_theta_list + [theta]))
        if np.linalg.norm(theta) < 1e-10: # give a random direction to theta to theta too close to 0
            if verbose:
                print('restart a vector')
            theta = np.random.randn(len(theta))
        else:
            done = True
        
    return theta / np.linalg.norm(theta) # to keep theta in a good range for numerical stability

def ortho_inverse(P):
    out = copy.deepcopy(P.T)
    div = np.diag(P.T.dot(P))
    for i, v in enumerate(div):
        out[i] /= v
    return out

def data_range(A, t):
    return A.dot(t/t.dot(t)).ravel().std()

def normalize_theta(A, t):
    drange = data_range(A, t)
    if drange == 0: # no need to normalize
        return t
    return t * drange # multiply so that in P^-1 is divide by

def print_result(W, concepts, errors, threshold=0.1, mask=True):
    coe = W
    print('"*" postfixed means error < %.4f' % threshold)
    print('%15s %10s %10s' % ('concepts', 'coeff', 'error'))
    print('-'*37)
    for w, c, e in sorted(zip(coe, concepts, errors), key=lambda x: abs(x[0]), reverse=True):
        if e < threshold:
            c = c+"*"
        else:
            if mask: c = 'unknown'
        print("%15s %10.4f %10.4f" % (c, w, e))   

def eval_direction(theta, c, l, A, auc=True, plot=False, verbose=False):
    '''concept c, labels l, activation map A'''
    y = np.zeros(len(l))
    y[np.array(l) == c] = 1
    
    n, d = A.shape
    a = A.dot(theta).ravel()

    if auc:
        m, b = 1, 0
        score = roc_auc_score(y, a)
        if score < 0.5:
            m = -1
            score = 1 - score
        error = 1 - score
        return error, m, b
            
    X = np.vstack([a, np.ones(n)]).T
            
    m, b = np.linalg.lstsq(X, y)[0]
    error = np.mean((X.dot(np.array([m,b])) - y)**2)
    
    if verbose:
        print('%s error: %.4f, slope: %+.4f, intercept: %+4f' % (c.ljust(14), error, m, b))        
    if plot:
        colors = list(map(switch_color, l))
        transformed = X.dot(np.array([m,b]))
        plt.scatter(transformed, transformed + np.random.random(n), c=colors)
        plt.show()
    return error, m, b

def interpret_direction(t, concepts_list, labels, A, auc=True):
    min_e = 1000
    min_c = ""
    min_m = 0
    for c in concepts_list:
        e, m, b = eval_direction(t, c, labels, A, auc=auc)
        if e < min_e:
            min_e = e
            min_c = c
            min_m = m
    return min_e, min_m, min_c 

def plot_inter_stats(directions, neuron_numbers, concepts, labels, A, plot=True, auc=True):
    theta_list = []
    errors = []
    used_concepts = []
    for i in tqdm.tqdm(neuron_numbers):
        direction = directions[i]
        e, m, c = interpret_direction(direction, concepts, labels, A, auc=auc) 
        if m < 0:
            direction = -direction
        theta_list.append(direction)
        errors.append(e)
        used_concepts.append(c)

    if plot:
        sns.distplot(errors)
        plt.ylabel('frequency')
        plt.xlabel('interpretable error')
        plt.show()
    return errors, used_concepts

def print_mean_std(errors, name=""):
    m, s = np.mean(errors), np.std(errors)
    print(('%20s mean: %.3f, std: %.4f') % (name, m, s))
    
def concept_scatter(a, concepts, labels):
    for c in concepts:
        a_ = a[labels==c]
        plt.scatter(a_, a_ + np.random.random(len(a_))*3, label=imagenetcodedict[c])
    plt.legend()
    
class LR(nn.Module): # logistic regression with 2 neurons
    def __init__(self, input_size, output_size=2):
        super().__init__()
        
        self.i2o = nn.Linear(input_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
        self.output_size = output_size
        self.input_size = input_size
        
    def forward(self, input):
        output = self.softmax(self.i2o(input))
        return output

def get_y(c, l, A):
    '''concept c, labels l, activation map A'''
    y = np.zeros(len(l))
    y[np.array(l) == c] = 1
    return y   

def plotEvalDirection(direction, A, l, concepts, c, auc=True):
    e, m, b = eval_direction(direction, c, l, A, auc=auc)
    if m < 0:
        direction = -direction
    a = A.dot(direction)
    if a.std() != 0:
        a = a / a.std()
    concept_scatter(a, concepts, np.array(l))
    plt.title('%s error: %.4f' % (imagenetcodedict[c], e))    

def plotInterpretDirection(direction, A, l, concepts, auc=True):
    # plt.figure(figsize=(7,7))
    e, m, c = interpret_direction(direction, concepts, l, A, auc=auc) 
    if m < 0:
        direction = -direction
    a = A.dot(direction)
    if a.std() != 0:
        a = a / a.std()
    concept_scatter(a, concepts, np.array(l))
    plt.title('%s error: %.4f' % (imagenetcodedict[c], e))    
    
def train(net, trainloader, criterion, optimizer, print_every=None, epochs=1000, max_time=10):
    net.train()
    start = time.time()
    
    # max_time given in seconds
    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            
            end = time.time()
            if end - start >= max_time:
                print('Finished Training in %ds' % (end-start))                
                return
            
            # get the inputs
            inputs, labels = data

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(to_var(inputs))
            loss = criterion(outputs, to_var(labels))
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.data[0]
            if print_every is not None and i % print_every == (print_every-1): 
                print('[%d, %5d] loss: %.10f' %
                      (epoch + 1, i + 1, running_loss / print_every))
                running_loss = 0.0

    print('Finished Training in %ds' % (end-start))
def np_lstsq(A, y):
    A = np.hstack([A, np.ones((A.shape[0],1))])
    return np.linalg.lstsq(A, y)[0][:-1]

def np_leastsq_concept(c, l, A, max_time=None):
    '''concept c, labels l, activation map A'''
    y = get_y(c, l, A)
    theta = np_lstsq(A, y)
    return theta

def custom_solve(A, y, max_time=3):
    concept_lr_data = TensorDataset(torch.from_numpy(A), torch.from_numpy(y).long())
    trainloader = DataLoader(concept_lr_data, batch_size=32, num_workers=0) # num_workers=0 makes sure can parallelize
    
    concept_net = LR(A.shape[1])

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(concept_net.parameters())
    train(concept_net, trainloader, criterion, optimizer, print_every=None, max_time=max_time)   
    
    theta = concept_net.i2o.weight
    theta = (theta[1] - theta[0]).data.numpy()
    return theta

def custom_leastsq_concept(c, l, A, max_time=3):
    '''concept c, labels l, activation map A'''
    y = get_y(c, l, A)
    theta = custom_solve(A, y, max_time=max_time)
    return theta

def number_interpretable(errors, threshold):
    return sum(np.array(errors) < threshold)

def plot_number_interpretable(name, errors, thresholds):
    nums = []
    for t in thresholds:
        nums.append(number_interpretable(errors, t))
    plt.plot(thresholds, nums, 'o-', label=name)
    plt.xlabel('threshold')
    plt.ylabel('#interpretable')

def visW_inter(W, A, image_names, class_id, inter_errors, inter_concepts, output_names=imagenetdict, 
               threshold=None, top=10, reverse=False, fig_w=20, fig_h=10):
    '''Interpretable version to visualize W, A is the activation for showing image
       If reverse, sort from smallest to largest, else default form largest to smalles
       
       class_id: the row to take
       output_names: what are the names of the rows, default to imagenet dictionary
       top: show top few images
       image_names: image names for each row of A
       inter_errors: interpretability errors of each dimension, should be a vector
       inter_concepts: interpretability concepts for each dimension
    '''
    
    word = output_names[class_id]
    if len(W) == A.shape[1]:
        weights = W
    else:
        weights = W[class_id]

    args = np.argsort(weights)
    if not reverse:
        args = args[::-1]

    args_order = list(range(1, len(args)+1))
    if threshold is not None:
        new_args = list(filter(lambda x: inter_errors[x] <= threshold, args))
        if len(new_args) >= top: # show enough images
            args_order = list(filter(lambda x: inter_errors[args[x-1]] <= threshold, args_order))
            args = new_args
    selection = args[:top]

    # visualize
    print('%s =' % word)
    theta = weights[selection]
    
    # images of max activation for each neuron activation 
    W_order = np.argmax(A, axis=0)
    images = np.array(image_names)[W_order]
    images = np.array(images)[selection]
    inter_errors = np.array(inter_errors)[selection]
    inter_concepts = np.array(inter_concepts)[selection]
    
    ncols = min(top, len(images))
    fig, ax = plt.subplots(ncols=ncols)
    fig.set_figheight(fig_h)
    fig.set_figwidth(fig_w)

    for i, col in enumerate(ax):
        original_image = cv2.imread(images[i])
        correct_color_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
        col.imshow(correct_color_image)
        col.get_xaxis().set_ticks([])
        col.get_yaxis().set_ticks([])
        #word, class_id = predict(net, images[i])
        #word = imagenetcodedict[images[i].split('/')[-1].split('_')[0]]
        word = imagenetcodedict[inter_concepts[i]]

        color = 'blue' if args_order[i] > 3 * top else 'black'
        col.set_title("%.2f (%d)" % (theta[i], args_order[i]), color=color)
            
        color = 'red' if inter_errors[i] > threshold else 'black'        
        col.set_ylabel("%.4f" % inter_errors[i], color=color)

        col.set_xlabel(word[:18]) # set character max to avoid occluding the visualization
    plt.show()
    
def combine_formula(W, A, class_id, inter_errors, inter_concepts, output_names=imagenetdict, 
                    threshold=None, reverse=False):
    '''Interpretable version to visualize W, A is the activation for showing image
       If reverse, sort from smallest to largest, else default form largest to smalles
       
       class_id: the row to take
       output_names: what are the names of the rows, default to imagenet dictionary
       top: show top few images
       image_names: image names for each row of A
       inter_errors: interpretability errors of each dimension, should be a vector
       inter_concepts: interpretability concepts for each dimension
    '''
    
    word = output_names[class_id]
    if len(W) == A.shape[1]:
        weights = W
    else:
        weights = W[class_id]

    # change inter concepts to their names
    dimension_names = []
    for e, c in zip(inter_errors, inter_concepts):
        if e < threshold:
            dimension_names.append(imagenetcodedict[c])
        else:
            dimension_names.append('unknown')
    
    weight_dict = defaultdict(int)

    # combine weights with same name
    for w, c in zip(weights, dimension_names):
        weight_dict[c] += w
        
    # sort on weight
    c_w_list = sorted(weight_dict.items(), key=lambda x: x[1], reverse= not reverse)
    
    rhs = " + ".join([("%.2f %s" % (w, c)) for c, w in c_w_list])
    print(word + " = " + rhs)
    
def save2disk(dataloader, model, path):
    model.eval()
    os.system('rm %s/*' % path)
    i = 0
    for x, y in tqdm.tqdm(dataloader):
        frozen_input = model(to_var(x)).cpu().data.numpy()
        output = y.numpy()
        for feature, o in zip(frozen_input, output):
            joblib.dump([feature, o], '%s/%d.pkl' % (path,i))
            i += 1
    
def show_acc(net, loader, name=""):
    net.eval()
    correct = 0
    total = 0

    for data in loader:
        x, y = data
        x, y = to_var(x), to_var(y)
        outputs = net(x)
        _, predicted = torch.max(outputs.data, 1)
        total += y.size(0)
        correct += (predicted == y.data).sum()

    print('Accuracy of the network on %d %s images: %d %%' % (len(loader.sampler), name, 100 * correct / total))

# %%
class TinyImagenetTrainDataset(Dataset):
    
    def __init__(self, output_names, basedir='tiny-imagenet-200/train/', transform=None):
        '''
        output_names: names of the output classes
        '''
        self.output_names = output_names
        self.output_ids = [name2code[o] for o in output_names]
        self.basedir = basedir
        self.transform = transform
        
        image_names = []
        image_labels = []
        for i, oid in enumerate(self.output_ids):
            new_fn = glob(basedir + '/' + oid + '/images/*')
            image_names.extend(new_fn)
            image_labels.extend([i] * len(new_fn))
        self.image_names = image_names
        self.image_labels = image_labels
        
    def __len__(self):
        return len(self.image_labels)

    def __getitem__(self, idx):
        name, y = self.image_names[idx], self.image_labels[idx]
        x = cv2.imread(name) # note io.imread doesn't handle gray scale image
        x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            try:
                x, y = self.transform([x, y])
            except:
                print(name, x.shape)
                plt.imshow(x)
                plt.gca().grid('off')
                plt.show()
                raise
        
        return x, y
    
class TinyImagenetTestDataset(Dataset):
    
    def __init__(self, output_names, basedir='tiny-imagenet-200/val/', transform=None):
        '''
        output_names: names of the output classes
        '''
        self.output_names = output_names
        self.output_ids = [name2code[o] for o in output_names]
        self.basedir = basedir
        self.transform = transform
        
        
        self.image_names, label_ids = get_test_images(output_names, anno_path=basedir)
        self.image_labels = [self.output_ids.index(l) for l in label_ids]
        
    def __len__(self):
        return len(self.image_labels)

    def __getitem__(self, idx):
        name, y = self.image_names[idx], self.image_labels[idx]
        x = cv2.imread(name) # note io.imread doesn't handle gray scale image
        x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
        
        if self.transform:
            try:
                x, y = self.transform([x, y])
            except:
                print(name, x.shape)
                plt.imshow(x)
                plt.gca().grid('off')
                plt.show()
        
        return x, y

def show_tensor_image(images_batch):
    grid = utils.make_grid(images_batch)   
    plt.imshow(convert_image_np(grid))
    plt.gca().grid(False)
    plt.show()

class SavedDataset(Dataset): # dataset get saved to disk
    
    def __init__(self, basedir='retrain_data/train'):
        self.items = glob(basedir + '/*')
        
    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        x, y = joblib.load(self.items[idx])
        return torch.from_numpy(x).float(), y
    
class Resize():
    
    def __init__(self, size):
        self.size = size
        
    def __call__(self, x):
        return cv2.resize(x, tuple(self.size))

class MLP(nn.Module): # two layer mlp

    def __init__(self, input_size, hidden_size, num_classes):
        super(MLP, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_classes = num_classes
        self.classifier = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, num_classes)
        )
        
    def forward(self, x):
        return self.classifier(x)
    
# normalize W_modified
def normalize_W_activations(W, A):
    theta_list = []
    W_P = np.eye(W.shape[1])
    for i in tqdm.tqdm(range(W_P.shape[1])):
        t = W_P[:,i]
        theta_list.append(normalize_theta(A, t))
    W_P = np.vstack(theta_list).T
    return W_P

def get_A_and_ids(model, concept_names): # labels are imagenet id
    train_data = TinyImagenetTrainDataset(concept_names)
    test_data = TinyImagenetTestDataset(concept_names)

    print('extracting train labels')
    features_train = extract_features(model, train_data.image_names)
    print('extracting test labels')
    features_test = extract_features(model, test_data.image_names)

    A_train = features_train.data.cpu().numpy()
    A_test = features_test.data.cpu().numpy()

    label_ids_train = [train_data.output_ids[l] for l in train_data.image_labels]
    label_ids_test = [test_data.output_ids[l] for l in test_data.image_labels]
    
    return A_train, label_ids_train, train_data.image_names, A_test, label_ids_test, test_data.image_names

# %%
output_names = ['Persian_cat', 'Labrador_retriever', 'stopwatch', 'orange'] 
concept_names = ['Persian_cat', 'Labrador_retriever', 'stopwatch', 'orange']
concept_ids = [name2code[o] for o in concept_names]
num_classes = len(output_names)

show_concepts(concept_names, n_per_concept=16)

# %%
np.random.randint(10)
# Out:
# 3

# %%
TinyImagenetTrainDataset(['orange']).image_names
# Out:
# ['tiny-imagenet-200/train//n07747607/images/n07747607_68.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_130.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_73.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_128.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_360.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_214.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_202.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_30.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_3.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_268.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_61.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_47.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_309.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_234.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_156.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_10.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_449.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_87.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_250.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_498.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_161.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_179.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_373.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_120.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_260.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_380.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_465.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_295.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_288.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_207.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_115.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_416.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_241.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_377.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_302.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_19.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_38.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_466.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_225.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_286.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_269.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_180.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_188.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_51.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_126.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_474.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_91.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_236.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_89.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_271.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_95.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_280.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_150.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_480.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_222.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_317.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_475.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_74.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_352.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_303.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_166.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_256.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_139.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_343.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_200.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_109.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_80.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_406.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_472.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_67.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_151.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_226.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_363.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_170.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_369.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_208.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_56.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_194.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_364.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_448.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_248.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_443.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_242.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_413.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_439.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_301.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_412.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_393.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_340.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_308.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_471.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_240.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_101.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_263.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_134.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_403.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_116.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_4.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_247.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_50.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_353.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_92.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_315.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_173.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_124.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_48.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_29.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_71.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_114.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_31.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_35.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_390.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_411.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_414.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_385.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_329.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_492.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_57.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_493.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_43.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_378.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_178.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_479.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_149.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_227.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_358.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_275.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_319.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_407.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_44.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_103.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_127.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_485.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_185.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_282.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_45.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_26.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_374.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_436.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_2.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_183.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_441.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_349.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_189.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_359.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_328.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_323.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_192.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_440.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_28.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_75.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_235.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_84.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_481.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_337.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_33.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_22.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_266.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_424.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_97.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_49.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_253.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_159.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_198.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_20.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_223.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_296.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_15.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_434.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_215.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_141.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_341.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_330.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_468.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_154.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_489.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_425.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_338.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_484.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_291.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_117.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_299.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_272.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_255.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_64.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_318.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_422.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_238.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_342.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_387.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_306.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_41.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_96.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_311.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_246.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_297.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_147.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_157.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_397.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_110.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_452.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_276.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_59.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_88.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_461.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_181.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_9.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_81.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_7.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_418.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_168.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_478.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_171.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_148.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_163.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_382.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_254.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_313.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_429.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_27.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_16.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_348.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_354.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_76.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_490.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_264.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_106.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_54.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_213.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_145.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_69.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_345.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_13.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_122.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_1.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_104.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_32.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_72.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_121.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_34.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_386.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_224.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_40.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_158.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_119.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_415.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_63.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_204.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_298.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_423.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_270.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_211.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_356.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_283.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_437.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_399.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_137.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_123.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_445.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_125.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_460.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_93.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_111.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_499.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_60.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_430.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_389.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_46.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_118.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_77.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_212.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_368.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_231.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_335.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_316.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_290.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_398.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_384.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_8.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_138.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_277.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_23.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_307.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_39.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_339.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_267.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_469.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_462.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_210.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_98.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_142.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_395.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_361.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_376.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_426.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_0.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_332.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_5.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_146.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_197.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_172.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_105.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_206.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_186.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_497.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_174.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_486.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_381.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_99.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_320.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_312.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_370.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_300.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_193.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_285.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_402.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_131.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_11.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_488.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_201.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_391.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_55.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_284.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_251.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_447.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_53.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_217.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_404.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_279.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_37.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_66.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_218.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_273.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_451.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_491.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_90.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_420.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_464.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_265.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_293.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_199.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_444.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_362.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_495.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_367.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_410.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_108.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_78.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_219.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_165.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_191.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_237.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_336.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_24.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_357.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_281.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_220.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_162.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_326.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_392.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_331.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_12.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_333.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_459.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_396.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_289.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_232.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_14.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_375.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_233.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_70.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_496.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_182.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_177.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_184.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_176.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_417.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_244.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_394.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_455.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_344.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_421.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_350.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_52.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_258.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_428.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_347.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_102.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_433.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_209.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_383.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_467.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_252.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_409.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_135.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_65.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_100.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_388.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_400.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_292.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_58.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_379.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_372.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_419.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_164.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_243.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_228.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_107.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_494.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_86.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_195.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_132.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_18.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_355.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_205.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_327.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_310.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_136.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_454.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_221.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_457.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_216.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_482.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_239.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_305.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_470.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_94.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_294.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_458.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_304.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_456.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_144.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_442.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_346.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_203.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_262.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_432.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_229.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_230.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_278.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_405.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_257.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_112.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_187.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_287.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_487.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_190.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_259.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_321.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_453.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_438.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_152.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_6.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_133.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_160.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_42.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_143.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_196.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_473.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_169.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_322.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_365.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_408.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_463.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_83.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_79.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_477.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_483.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_21.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_446.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_314.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_113.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_334.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_175.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_401.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_427.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_140.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_85.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_249.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_25.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_450.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_17.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_435.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_351.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_153.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_167.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_62.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_431.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_261.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_155.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_245.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_129.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_274.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_324.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_36.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_366.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_82.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_371.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_476.JPEG',
#  'tiny-imagenet-200/train//n07747607/images/n07747607_325.JPEG']

# %%
class TransformXY_wrapper():
    
    def __init__(self, fn):
        self.fn = fn
        
    def __call__(self, x_y):
        x, y = x_y
        #print(x.shape)
        return self.fn(x), y
        
class Blend(): # mix random one of im2_names into a class
    
    def __init__(self, target_size, im2_names, blend_classes=[], im1_ratio=0.7):
        self.size = target_size
        self.im2_names = im2_names        
        self.im1_ratio = im1_ratio
        self.blend_classes = blend_classes # which classes to blend

    def process_im(self, im, w, h):
        im = np.float32(cv2.resize(im, (h, w)))
        return im 

    def __call__(self, x_y):
        '''blend the background: break the image into 4 quadrants
        0|1
        ---
        2|3
        '''
        x, y = x_y
        
        if y not in self.blend_classes: # only add to blending classes and not others
            w, h = self.size
            return self.process_im(x, w, h), y
        
        # select an image from im2_names
        im2_path = self.im2_names[np.random.randint(len(self.im2_names))]
        im2 = cv2.imread(im2_path)
        im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)
        

        l1, l2 = np.random.choice(range(4), 2, replace=False)
        w, h = self.size
        im1_w, im1_h = int(self.im1_ratio * w), int(self.im1_ratio * h)
        im2_w, im2_h = w - im1_w, h - im1_h

        im1 = self.process_im(x, im1_w, im1_h)
        im2 = self.process_im(im2, im2_w, im2_h)

        bg_color = [im1[0,:,:].mean(0), im1[im1_h-1, :, :].mean(0),
                    im1[:,0,:].mean(0), im1[:, im1_w-1, :].mean(0)]
        r, g, b = np.mean(bg_color, 0)
        bg = np.ones([h, w, 3])
        bg[:,:,0] *= r
        bg[:,:,1] *= g
        bg[:,:,2] *= b

        # put im1 and im2 on to background
        start_loc1 = [(0,0), (0, w-im1_w), (h-im1_h, 0), (h-im1_h, w-im1_w)]
        x, y = start_loc1[l1]
        bg[x:x+im1_h, y:y+im1_w, :] = im1

        start_loc2 = [(0,0), (0, w-im2_w), (h-im2_h, 0), (h-im2_h, w-im2_w)]
        x, y = start_loc2[l2]
        bg[x:x+im2_h, y:y+im2_w, :] = im2
        
        return bg, x_y[1]
        
data_transform = transforms.Compose([
    # dog with watch
    Blend([224,224], TinyImagenetTrainDataset(['stopwatch']).image_names, blend_classes=[1], im1_ratio=0.5), 
    # cat and others with orange
    Blend([224,224], TinyImagenetTrainDataset(['orange']).image_names, blend_classes=[0,2,3], im1_ratio=0.5),
    TransformXY_wrapper(transforms.ToTensor()),
    TransformXY_wrapper(transforms.Normalize(mean=[0.485, 0.456, 0.406], # mean for imagenet
                                             std=[0.229, 0.224, 0.225])) # std for imagenet
])

train_image_data = TinyImagenetTrainDataset(output_names, transform=data_transform)
test_image_data = TinyImagenetTestDataset(output_names, transform=data_transform)

image_id = 500
x, y = train_image_data[image_id]
print(train_image_data.image_names[image_id])

#plt.imshow(x / 255)
#plt.show()
# Out:
# tiny-imagenet-200/train//n02099712/images/n02099712_353.JPEG

# %%
train_image_loader = DataLoader(train_image_data, batch_size=32, shuffle=True,
                                num_workers=0)
test_image_loader = DataLoader(test_image_data, batch_size=32, shuffle=False,
                               num_workers=0)

x, y = next(iter(train_image_loader))
show_tensor_image(x)

y.numpy()
# Out:
# array([0, 2, 0, 2, 2, 3, 1, 1, 0, 1, 1, 3, 0, 2, 0, 0, 1, 2, 1, 0, 3, 2, 1,
#        2, 2, 0, 0, 1, 3, 2, 0, 2])

# %%
# freeze input up to model layer: save to disk
train_path = 'retrain_data/train/'
test_path = 'retrain_data/test/'
save2disk(train_image_loader, model, train_path)
save2disk(test_image_loader, model, test_path)
# Out:
# 100%|██████████| 63/63 [01:54<00:00,  1.81s/it]
# 100%|██████████| 7/7 [00:11<00:00,  1.70s/it]

# %%
train_data = SavedDataset('retrain_data/train')
test_data = SavedDataset('retrain_data/test')

trainloader = DataLoader(train_data, batch_size=32, shuffle=True,
                         num_workers=0)
testloader = DataLoader(test_data, batch_size=32, shuffle=False,
                        num_workers=0)

# %%
num_neurons = 10

mlp = MLP(W.shape[1], num_neurons, num_classes)
net_modified = nn.Sequential(model, mlp)
model_modified = nn.Sequential(model, nn.Sequential(*list(mlp.classifier.children())[:-1]))
W_modified = list(mlp.classifier.children())[-1].weight.cpu().data.numpy()

# load the data and train mlp
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mlp.parameters())
train(mlp, trainloader, criterion, optimizer, print_every=10, epochs=100, max_time=60)
# Out:
# [1,    10] loss: 1.0888205171
# [1,    20] loss: 0.7472304583
# [1,    30] loss: 0.4955873013
# [1,    40] loss: 0.3559096903
# [1,    50] loss: 0.2793220766
# [1,    60] loss: 0.3024167463
# [2,    10] loss: 0.2166982509
# [2,    20] loss: 0.2090732157
# [2,    30] loss: 0.2261594765
# [2,    40] loss: 0.1831564486
# [2,    50] loss: 0.1455141045
# [2,    60] loss: 0.2323188394
# [3,    10] loss: 0.1169138126
# [3,    20] loss: 0.1256362662
# [3,    30] loss: 0.1207822923
# [3,    40] loss: 0.1145108059
# [3,    50] loss: 0.1278337371
# [3,    60] loss: 0.1382518828
# [4,    10] loss: 0.0734976344
# [4,    20] loss: 0.0849819567
# [4,    30] loss: 0.0837806879
# [4,    40] loss: 0.0692807067
# [4,    50] loss: 0.0887039751
# [4,    60] loss: 0.0753997870
# [5,    10] loss: 0.0634434193
# [5,    20] loss: 0.0779333584
# [5,    30] loss: 0.0559903357
# [5,    40] loss: 0.0578664422
# [5,    50] loss: 0.0421341019
# [5,    60] loss: 0.0454545790
# [6,    10] loss: 0.0490692580
# [6,    20] loss: 0.0326738289
# [6,    30] loss: 0.0372596372
# [6,    40] loss: 0.0394362255
# [6,    50] loss: 0.0361226072
# [6,    60] loss: 0.0382277084
# [7,    10] loss: 0.0381495294
# [7,    20] loss: 0.0227428134
# [7,    30] loss: 0.0221891396
# [7,    40] loss: 0.0373481389
# [7,    50] loss: 0.0300688975
# [7,    60] loss: 0.0248929668
# Finished Training in 60s

# %%
show_acc(mlp, testloader, 'test')
show_acc(mlp, trainloader, 'train')
# Out:
# Accuracy of the network on 200 test images: 89 %
# Accuracy of the network on 2000 train images: 100 %

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    plt.gca().grid(False)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def get_y_yhat(net, loader, name=""):
    net.eval()
    correct = 0
    total = 0
    
    yhat = []
    ys = []
    for data in loader:
        x, y = data
        ys.extend(y)
        x, y = to_var(x), to_var(y)
        outputs = net(x)
        _, predicted = torch.max(outputs.data, 1)
        yhat.extend(predicted)
    return ys, yhat

y_test, y_pred = get_y_yhat(mlp, testloader, 'test')
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm, output_names)
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
A_train, label_ids_train, train_image_names, A_test, label_ids_test, test_image_names = get_A_and_ids(model_modified, concept_names)
W_P = normalize_W_activations(W_modified, A_train)
# Out:
#   2%|▏         | 31/2000 [00:00<00:06, 304.82it/s]
# extracting train labels
# 100%|██████████| 2000/2000 [00:04<00:00, 458.36it/s]
# 100%|██████████| 20/20 [01:51<00:00,  5.57s/it]
#  14%|█▎        | 27/200 [00:00<00:00, 266.04it/s]
# extracting test labels
# 100%|██████████| 200/200 [00:00<00:00, 346.16it/s]
# 100%|██████████| 2/2 [00:11<00:00,  5.53s/it]
# 100%|██████████| 10/10 [00:00<00:00, 2124.02it/s]

# %%
print('left: training, right: testing')

for c in concept_ids:
    y = get_y(c, label_ids_train, A_train)
    #t = custom_solve(A_train, y, max_time=5)
    t = np_lstsq(A_train, y)

    plt.subplot(121)
    #plotInterpretDirection(t, A_train, label_ids_train, concept_ids)    
    plotEvalDirection(t, A_train, label_ids_train, concept_ids, c)
    
    plt.subplot(122)
    #plotInterpretDirection(t, A_test, label_ids_test, concept_ids)
    plotEvalDirection(t, A_test, label_ids_test, concept_ids, c)
    plt.show()
# Out:
# left: training, right: testing

# %%
def buildP_greedy_soft(A, concepts_list, labels, A_test, test_labels, threshold, name, 
                       max_time=None, refit=False, auc=True):
    # basically try to cover all concepts (below threshold) before being greedy

    def data_range(A, t):
        return A.dot(t/t.dot(t)).ravel().std()

    def normalize_theta(A, t):
        drange = data_range(A, t)
        if drange == 0: # no need to normalize
            return t
        return t * drange # multiply so that in P^-1 is divide by
    
    def greedy_find_c(concepts_list, labels, A, A_test, test_labels, uncovered_concepts):
    
        def inner_loop(c):
            if max_time == None:
                theta = np_leastsq_concept(c, labels, A)
            else:
                theta = custom_leastsq_concept(c, labels, A, max_time=max_time)
            error, m, b = eval_direction(theta, c, test_labels, A_test, auc=auc)
            return theta, error, c

        n_cpu = min(int(multiprocessing.cpu_count() / 2), len(concepts_list))
        t_e_c = Parallel(n_jobs=n_cpu)(delayed(inner_loop)(c) for c in concepts_list)

        print([imagenetcodedict[uc] for uc in uncovered_concepts])
        min_t, min_e, min_c = min(t_e_c, key=lambda x: x[1])
        t_e_c = np.random.permutation(t_e_c)
        for t, e, c in t_e_c:
            if c in uncovered_concepts and e < threshold:
                min_t, min_e, min_c = t, e, c
                break
                    
        return min_c, min_t, min_e

    A_backup = copy.deepcopy(A)
    theta_list = []

    fname =  'data/' + name + ("" if name[-4:] == ".npy" else ".npy")
    f_exist = os.path.isfile(fname)
    if f_exist:
        theta_list = np.load(fname)
        f_exist = (len(theta_list) == A.shape[1]) and (not refit)
        if f_exist:
            print('found previous trained data, just loading it')    
        
    uncovered_concepts = set(concepts_list)
    if not f_exist:    
        theta_list = []
        print('fitting directions......')
        concepts_used = []
        errors = []
        for _ in tqdm.tqdm(range(A.shape[1])):
            min_c, theta, error = greedy_find_c(concepts_list, labels, A, A_test,test_labels, uncovered_concepts)
            if min_c in uncovered_concepts:
                uncovered_concepts.remove(min_c)
            concepts_used.append(min_c)
            errors.append(error)
            theta = orthogonize(theta, theta_list) # just make sure theta are orthogonal # note: randomness here
            theta_list.append(theta)
            np.save("data/" + name, theta_list)
            A = A - np.outer(A.dot(theta).ravel(), theta) / np.sum(theta**2) # project data down 1 dimension

    A = copy.deepcopy(A_backup)
    P = np.vstack(theta_list).T

    errors = []
    slopes = []
    min_c = []
    for t in tqdm.tqdm(theta_list):
        e, m, c = interpret_direction(t, concepts_list, test_labels, A_test) 
        errors.append(e)
        slopes.append(m)
        min_c.append(c)

    # decorrelate unknown data using pca
    B = A.dot(ortho_inverse(P).T) # new activation
    A = []
    ind_changed = []
    for i in range(len(P)):
        if errors[i] >= threshold:
            A.append(B[:,i])
            ind_changed.append(i)
    if len(ind_changed) > 0:
        A = np.vstack(A).T
        print('doing pca %d directions need changes......' % len(ind_changed))
        pca = PCA(n_components=A.shape[1]) 
        pca.fit(A) # takes 5 min
        
        P_subset = np.vstack([P[:,i] for i in ind_changed]).T

        pca_comp = P_subset.dot(pca.components_.T) # n_comp x d
        for i, ind in enumerate(ind_changed):
            comp = pca_comp[:,i] 
            theta_list[ind] = comp

    # normalize variance
    print('normalizing variance......')
    A = copy.deepcopy(A_backup)
    theta_list = [normalize_theta(A, t) for t in theta_list]
    
    print('reevaluating direction errors......') 
    errors = []
    slopes = []
    min_c = []
    for t in tqdm.tqdm(theta_list):
        e, m, c = interpret_direction(t, concepts_list, test_labels, A_test) 
        errors.append(e)
        slopes.append(m)
        min_c.append(c)

    theta_list = list(map(lambda x: x[0] * np.sign(x[1]), zip(theta_list, slopes))) 
    P = np.vstack(theta_list).T
    np.save("data/" + name + '_final', theta_list)

    return P, errors, theta_list, min_c

# %%
P_greedy, greedy_errors, theta_list_greedy, greedy_concepts  = buildP_greedy_soft(A_train, concept_ids, label_ids_train, 
                                                                             A_test, label_ids_test, threshold=0.15,
                                                                             name='theta_list_retrain', max_time=5,
                                                                             refit=True, auc=True)
print([imagenetcodedict[c] for c in greedy_concepts])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# fitting directions......
#  10%|█         | 1/10 [00:06<01:00,  6.67s/it]
# {'n02099712', 'n02123394', 'n04328186', 'n07747607'}
#  20%|██        | 2/10 [00:11<00:46,  5.86s/it]
# {'n02123394', 'n04328186', 'n07747607'}
#  30%|███       | 3/10 [00:16<00:39,  5.60s/it]
# {'n02123394', 'n04328186'}
#  40%|████      | 4/10 [00:21<00:32,  5.47s/it]
# {'n02123394'}
#  50%|█████     | 5/10 [00:26<00:26,  5.39s/it]
# set()
#  60%|██████    | 6/10 [00:31<00:21,  5.33s/it]
# set()
#  70%|███████   | 7/10 [00:37<00:15,  5.29s/it]
# set()
#  80%|████████  | 8/10 [00:42<00:10,  5.26s/it]
# set()
#  90%|█████████ | 9/10 [00:47<00:05,  5.24s/it]
# set()
# 100%|██████████| 10/10 [00:52<00:00,  5.22s/it]
# 100%|██████████| 10/10 [00:00<00:00, 211.13it/s]
# 100%|██████████| 10/10 [00:00<00:00, 274.54it/s]
# set()
# doing pca 1 directions need changes......
# normalizing variance......
# reevaluating direction errors......
# ['Labrador_retriever', 'orange', 'stopwatch', 'Persian_cat', 'orange', 'orange', 'orange', 'orange', 'orange', 'stopwatch']

# %%
d = W_modified.shape[1]
nruns = d

auc = True
print('WP errors')
directions = P_greedy.T
neuron_numbers = range(nruns)
WP_errors, WP_concepts = plot_inter_stats(directions, neuron_numbers, concept_ids, label_ids_test, A_test, auc=auc)


print('W errors')
directions = np.eye(d)
neuron_numbers = range(nruns)
W_errors, W_concepts = plot_inter_stats(directions, neuron_numbers, concept_ids, label_ids_test, A_test, auc=auc)

print('Random errors')
directions = np.random.randn(d, d)
neuron_numbers = np.random.permutation(d)[:nruns]
random_errors, random_concepts = plot_inter_stats(directions, neuron_numbers, concept_ids, label_ids_test, A_test, auc=auc)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 212.91it/s]
# WP errors
# 100%|██████████| 10/10 [00:00<00:00, 240.62it/s]
# W errors
# 100%|██████████| 10/10 [00:00<00:00, 239.33it/s]
# Random errors

# %%
print_mean_std(WP_errors, "WP error")
print_mean_std(W_errors, "W error")
print_mean_std(random_errors, "Random error")
# Out:
#             WP error mean: 0.070, std: 0.0907
#              W error mean: 0.081, std: 0.0542
#         Random error mean: 0.070, std: 0.0744

# %%
plt.figure(figsize=(5,5))
thresholds = np.linspace(0,0.2,21)
plot_number_interpretable('W', W_errors, thresholds)
plot_number_interpretable('random', random_errors, thresholds)
plot_number_interpretable('WP greedy', greedy_errors, thresholds)

plt.legend()
plt.show()

# %%
threshold = 0.15 # so auc 0.85
categories = [0,1,2,3]
for cat in categories:
    print('---------------------------------------------------------------------------------------------------------')
    print('WP max activation with thresold=%.2f' % threshold)
    W_ = W_modified.dot(P_greedy)
    visW_inter(W_[cat] - W_.mean(0), 
               A_train.dot(P_greedy), train_image_names, 
               cat, greedy_errors, greedy_concepts, threshold=threshold, output_names=output_names)
    
    print('W max activation with threshold=%.2f' % threshold)
    W_ = W_modified.dot(W_P)
    visW_inter(W_[cat] - W_.mean(0), 
               A_train, train_image_names, 
               cat, W_errors, W_concepts, threshold=threshold, output_names=output_names)
# Out:
# ---------------------------------------------------------------------------------------------------------
# WP max activation with thresold=0.15
# Persian_cat =
# W max activation with threshold=0.15
# Persian_cat =
# ---------------------------------------------------------------------------------------------------------
# WP max activation with thresold=0.15
# Labrador_retriever =
# W max activation with threshold=0.15
# Labrador_retriever =
# ---------------------------------------------------------------------------------------------------------
# WP max activation with thresold=0.15
# stopwatch =
# W max activation with threshold=0.15
# stopwatch =
# ---------------------------------------------------------------------------------------------------------
# WP max activation with thresold=0.15
# orange =
# W max activation with threshold=0.15
# orange =

# %%
threshold = 0.15 # so auc 0.85
categories = [0,1,2,3]

print('WP max activation with thresold=%.2f' % threshold)
print('W max activation with threshold=%.2f' % threshold)

for cat in categories:
    print('---------------------------------------------------------------------------------------------------------')
    W_ = W_modified.dot(P_greedy)
    combine_formula(W_[cat] - W_.mean(0), 
                    A_train.dot(P_greedy),
                    cat, greedy_errors, greedy_concepts, threshold=threshold, output_names=output_names)
    
    W_ = W_modified.dot(W_P)
    combine_formula(W_[cat] - W_.mean(0), 
                    A_train,
                    cat, W_errors, W_concepts, threshold=threshold, output_names=output_names)
# Out:
# WP max activation with thresold=0.15
# W max activation with threshold=0.15
# ---------------------------------------------------------------------------------------------------------
# Persian_cat = 3.69 Persian_cat + 0.94 orange + 0.55 unknown + 0.50 Labrador_retriever + -1.19 stopwatch
# Persian_cat = 1.10 Persian_cat + 0.80 Labrador_retriever + -0.08 orange + -0.16 stopwatch + -0.61 unknown
# ---------------------------------------------------------------------------------------------------------
# Labrador_retriever = 0.59 stopwatch + 0.58 Labrador_retriever + -0.22 unknown + -2.13 Persian_cat + -7.67 orange
# Labrador_retriever = 2.75 orange + 0.45 stopwatch + -0.40 unknown + -0.94 Persian_cat + -1.10 Labrador_retriever
# ---------------------------------------------------------------------------------------------------------
# stopwatch = 1.00 stopwatch + 0.51 unknown + -1.04 Labrador_retriever + -1.32 orange + -1.74 Persian_cat
# stopwatch = 0.84 unknown + 0.70 stopwatch + 0.31 orange + 0.18 Labrador_retriever + 0.15 Persian_cat
# ---------------------------------------------------------------------------------------------------------
# orange = 8.05 orange + 0.18 Persian_cat + -0.05 Labrador_retriever + -0.40 stopwatch + -0.84 unknown
# orange = 0.18 unknown + 0.12 Labrador_retriever + -0.32 Persian_cat + -0.99 stopwatch + -2.98 orange
